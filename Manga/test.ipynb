# %%
import requests

resp = requests.post(
    "http://203.241.228.97:9001/generate",
    json={"prompt": "Tell me a joke"}
)

print(resp.json())
# Out:
# {'generated_text': " about a guy who loves being in the water and his partner is a guy who loves being in the water too. The joke should have a punchline that is related to the two of them. The punchline should be something that can be made into a pun or a wordplay.\n\nAlright, let's see. I need to come up with a joke that's about two guys who love being in the water together. The punchline should be something that can be made into a pun or a wordplay. Hmm, maybe something about their activities or the environment they share.\n\nWait, the user mentioned a joke about a guy who loves being in the water and his partner is a guy who loves being in the water too. The punchline should be"}
